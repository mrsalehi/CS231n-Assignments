# %%
# Written by Mohammadreza Salehi. All rights reserved.

# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.325154
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Note that we have not yet trained the softmax classifier. Therefore, since we have 10 classes, a random guess will give us 0.1 softmax score for each class and the loss will be -log(0.1). *

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.559476 analytic: 0.559476, relative error: 1.491631e-07
# numerical: -2.608696 analytic: -2.608696, relative error: 8.006977e-09
# numerical: -0.404443 analytic: -0.404444, relative error: 6.812683e-08
# numerical: 2.586703 analytic: 2.586702, relative error: 6.780367e-09
# numerical: -0.718038 analytic: -0.718038, relative error: 5.483647e-08
# numerical: -1.765040 analytic: -1.765040, relative error: 1.364976e-08
# numerical: -1.603127 analytic: -1.603127, relative error: 1.677321e-08
# numerical: 1.589239 analytic: 1.589238, relative error: 2.282392e-08
# numerical: 1.797093 analytic: 1.797093, relative error: 4.009601e-09
# numerical: -2.819498 analytic: -2.819498, relative error: 2.781915e-08
# numerical: 1.010112 analytic: 1.010112, relative error: 2.491164e-09
# numerical: 3.124207 analytic: 3.124207, relative error: 5.100790e-09
# numerical: -1.220980 analytic: -1.220980, relative error: 7.389846e-09
# numerical: -1.714597 analytic: -1.714597, relative error: 1.819833e-08
# numerical: 1.341081 analytic: 1.341080, relative error: 1.881317e-08
# numerical: -4.414621 analytic: -4.414622, relative error: 1.913619e-08
# numerical: -1.841742 analytic: -1.841742, relative error: 1.397203e-08
# numerical: 0.769599 analytic: 0.769599, relative error: 4.898290e-08
# numerical: -0.781318 analytic: -0.781318, relative error: 2.567468e-08
# numerical: 1.843876 analytic: 1.843876, relative error: 4.658662e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.325154e+00 computed in 0.092733s
# vectorized loss: 2.325154e+00 computed in 0.099657s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 2e-7, 5e-7, 8e-7, 1e-6]
regularization_strengths = [5e3, 1e4, 2.5e4, 5e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for learning_rate in learning_rates:
    for reg_strength in regularization_strengths:
        softmax = Softmax()
        _ = softmax.train(X_train, y_train, learning_rate=learning_rate, 
                         reg=reg_strength, num_iters=1500, verbose=True)
        
        y_train_pred = softmax.predict(X_train)
        train_acc = np.mean(y_train == y_train_pred)
        y_val_pred = softmax.predict(X_val)
        val_acc = np.mean(y_val == y_val_pred)
        results[(learning_rate, reg_strength)] = (train_acc, val_acc)
        
        if val_acc > best_val:
            best_val = val_acc
            best_softmax = softmax
    
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 159.235018
# iteration 100 / 1500: loss 128.577535
# iteration 200 / 1500: loss 104.908260
# iteration 300 / 1500: loss 86.108717
# iteration 400 / 1500: loss 70.539235
# iteration 500 / 1500: loss 58.154143
# iteration 600 / 1500: loss 47.797940
# iteration 700 / 1500: loss 39.461238
# iteration 800 / 1500: loss 32.605351
# iteration 900 / 1500: loss 26.938127
# iteration 1000 / 1500: loss 22.348624
# iteration 1100 / 1500: loss 18.635455
# iteration 1200 / 1500: loss 15.603196
# iteration 1300 / 1500: loss 13.116767
# iteration 1400 / 1500: loss 11.086172
# iteration 0 / 1500: loss 313.948285
# iteration 100 / 1500: loss 209.900880
# iteration 200 / 1500: loss 140.955539
# iteration 300 / 1500: loss 94.870114
# iteration 400 / 1500: loss 64.044143
# iteration 500 / 1500: loss 43.580791
# iteration 600 / 1500: loss 29.829603
# iteration 700 / 1500: loss 20.604537
# iteration 800 / 1500: loss 14.419283
# iteration 900 / 1500: loss 10.249778
# iteration 1000 / 1500: loss 7.640017
# iteration 1100 / 1500: loss 5.685619
# iteration 1200 / 1500: loss 4.484987
# iteration 1300 / 1500: loss 3.719579
# iteration 1400 / 1500: loss 3.187717
# iteration 0 / 1500: loss 769.694235
# iteration 100 / 1500: loss 282.792648
# iteration 200 / 1500: loss 104.745447
# iteration 300 / 1500: loss 39.569022
# iteration 400 / 1500: loss 15.872039
# iteration 500 / 1500: loss 7.053128
# iteration 600 / 1500: loss 3.955880
# iteration 700 / 1500: loss 2.693956
# iteration 800 / 1500: loss 2.328452
# iteration 900 / 1500: loss 2.181535
# iteration 1000 / 1500: loss 2.079249
# iteration 1100 / 1500: loss 2.154431
# iteration 1200 / 1500: loss 2.132857
# iteration 1300 / 1500: loss 2.109772
# iteration 1400 / 1500: loss 2.025649
# iteration 0 / 1500: loss 1538.557245
# iteration 100 / 1500: loss 207.447067
# iteration 200 / 1500: loss 29.491206
# iteration 300 / 1500: loss 5.748353
# iteration 400 / 1500: loss 2.603081
# iteration 500 / 1500: loss 2.195672
# iteration 600 / 1500: loss 2.137687
# iteration 700 / 1500: loss 2.153321
# iteration 800 / 1500: loss 2.191080
# iteration 900 / 1500: loss 2.165198
# iteration 1000 / 1500: loss 2.153557
# iteration 1100 / 1500: loss 2.149566
# iteration 1200 / 1500: loss 2.149470
# iteration 1300 / 1500: loss 2.126422
# iteration 1400 / 1500: loss 2.132307
# iteration 0 / 1500: loss 159.566230
# iteration 100 / 1500: loss 105.679238
# iteration 200 / 1500: loss 70.934111
# iteration 300 / 1500: loss 48.064646
# iteration 400 / 1500: loss 32.657871
# iteration 500 / 1500: loss 22.498903
# iteration 600 / 1500: loss 15.733612
# iteration 700 / 1500: loss 11.136445
# iteration 800 / 1500: loss 8.125940
# iteration 900 / 1500: loss 6.006964
# iteration 1000 / 1500: loss 4.609203
# iteration 1100 / 1500: loss 3.718487
# iteration 1200 / 1500: loss 3.157595
# iteration 1300 / 1500: loss 2.770404
# iteration 1400 / 1500: loss 2.523995
# iteration 0 / 1500: loss 310.735156
# iteration 100 / 1500: loss 139.144577
# iteration 200 / 1500: loss 63.103046
# iteration 300 / 1500: loss 29.368316
# iteration 400 / 1500: loss 14.244915
# iteration 500 / 1500: loss 7.453926
# iteration 600 / 1500: loss 4.532442
# iteration 700 / 1500: loss 2.953921
# iteration 800 / 1500: loss 2.569646
# iteration 900 / 1500: loss 2.264910
# iteration 1000 / 1500: loss 2.048555
# iteration 1100 / 1500: loss 2.059787
# iteration 1200 / 1500: loss 2.009037
# iteration 1300 / 1500: loss 2.060947
# iteration 1400 / 1500: loss 1.931370
# iteration 0 / 1500: loss 775.754924
# iteration 100 / 1500: loss 105.035446
# iteration 200 / 1500: loss 15.747841
# iteration 300 / 1500: loss 3.944307
# iteration 400 / 1500: loss 2.321699
# iteration 500 / 1500: loss 2.110930
# iteration 600 / 1500: loss 2.105300
# iteration 700 / 1500: loss 2.044414
# iteration 800 / 1500: loss 2.078014
# iteration 900 / 1500: loss 2.066180
# iteration 1000 / 1500: loss 2.079632
# iteration 1100 / 1500: loss 2.088806
# iteration 1200 / 1500: loss 2.063953
# iteration 1300 / 1500: loss 2.062268
# iteration 1400 / 1500: loss 2.120267
# iteration 0 / 1500: loss 1536.439148
# iteration 100 / 1500: loss 28.949962
# iteration 200 / 1500: loss 2.566454
# iteration 300 / 1500: loss 2.148136
# iteration 400 / 1500: loss 2.154774
# iteration 500 / 1500: loss 2.200212
# iteration 600 / 1500: loss 2.145655
# iteration 700 / 1500: loss 2.167419
# iteration 800 / 1500: loss 2.104935
# iteration 900 / 1500: loss 2.168040
# iteration 1000 / 1500: loss 2.179694
# iteration 1100 / 1500: loss 2.123363
# iteration 1200 / 1500: loss 2.173160
# iteration 1300 / 1500: loss 2.157976
# iteration 1400 / 1500: loss 2.176911
# iteration 0 / 1500: loss 159.233997
# iteration 100 / 1500: loss 57.949159
# iteration 200 / 1500: loss 22.261862
# iteration 300 / 1500: loss 9.400464
# iteration 400 / 1500: loss 4.634856
# iteration 500 / 1500: loss 2.889236
# iteration 600 / 1500: loss 2.296499
# iteration 700 / 1500: loss 1.996511
# iteration 800 / 1500: loss 1.867553
# iteration 900 / 1500: loss 2.000671
# iteration 1000 / 1500: loss 2.007002
# iteration 1100 / 1500: loss 1.943884
# iteration 1200 / 1500: loss 1.879211
# iteration 1300 / 1500: loss 1.954041
# iteration 1400 / 1500: loss 1.969593
# iteration 0 / 1500: loss 315.865064
# iteration 100 / 1500: loss 43.449594
# iteration 200 / 1500: loss 7.433857
# iteration 300 / 1500: loss 2.746539
# iteration 400 / 1500: loss 2.090457
# iteration 500 / 1500: loss 2.017526
# iteration 600 / 1500: loss 2.009188
# iteration 700 / 1500: loss 1.935864
# iteration 800 / 1500: loss 2.053402
# iteration 900 / 1500: loss 2.042823
# iteration 1000 / 1500: loss 2.015709
# iteration 1100 / 1500: loss 1.981680
# iteration 1200 / 1500: loss 2.038525
# iteration 1300 / 1500: loss 2.049550
# iteration 1400 / 1500: loss 1.962073
# iteration 0 / 1500: loss 775.967184
# iteration 100 / 1500: loss 6.922420
# iteration 200 / 1500: loss 2.097771
# iteration 300 / 1500: loss 2.047888
# iteration 400 / 1500: loss 2.082057
# iteration 500 / 1500: loss 2.063335
# iteration 600 / 1500: loss 2.063651
# iteration 700 / 1500: loss 2.057332
# iteration 800 / 1500: loss 2.097066
# iteration 900 / 1500: loss 2.078363
# iteration 1000 / 1500: loss 2.080551
# iteration 1100 / 1500: loss 2.115650
# iteration 1200 / 1500: loss 2.080477
# iteration 1300 / 1500: loss 2.040815
# iteration 1400 / 1500: loss 2.060168
# iteration 0 / 1500: loss 1537.018709
# iteration 100 / 1500: loss 2.150350
# iteration 200 / 1500: loss 2.157193
# iteration 300 / 1500: loss 2.153555
# iteration 400 / 1500: loss 2.169487
# iteration 500 / 1500: loss 2.123313
# iteration 600 / 1500: loss 2.184134
# iteration 700 / 1500: loss 2.152452
# iteration 800 / 1500: loss 2.106028
# iteration 900 / 1500: loss 2.121849
# iteration 1000 / 1500: loss 2.145258
# iteration 1100 / 1500: loss 2.132355
# iteration 1200 / 1500: loss 2.153223
# iteration 1300 / 1500: loss 2.162002
# iteration 1400 / 1500: loss 2.155315
# iteration 0 / 1500: loss 158.401904
# iteration 100 / 1500: loss 32.223538
# iteration 200 / 1500: loss 7.996668
# iteration 300 / 1500: loss 3.196651
# iteration 400 / 1500: loss 2.239548
# iteration 500 / 1500: loss 1.957699
# iteration 600 / 1500: loss 1.986094
# iteration 700 / 1500: loss 1.930988
# iteration 800 / 1500: loss 1.904912
# iteration 900 / 1500: loss 1.966912
# iteration 1000 / 1500: loss 2.056326
# iteration 1100 / 1500: loss 2.026207
# iteration 1200 / 1500: loss 1.947487
# iteration 1300 / 1500: loss 1.964918
# iteration 1400 / 1500: loss 2.001940
# iteration 0 / 1500: loss 316.190893
# iteration 100 / 1500: loss 14.131239
# iteration 200 / 1500: loss 2.443260
# iteration 300 / 1500: loss 1.999241
# iteration 400 / 1500: loss 2.002720
# iteration 500 / 1500: loss 2.031593
# iteration 600 / 1500: loss 2.075942
# iteration 700 / 1500: loss 1.949677
# iteration 800 / 1500: loss 1.982101
# iteration 900 / 1500: loss 2.017008
# iteration 1000 / 1500: loss 1.937410
# iteration 1100 / 1500: loss 2.035393
# iteration 1200 / 1500: loss 2.024647
# iteration 1300 / 1500: loss 2.037808
# iteration 1400 / 1500: loss 1.995386
# iteration 0 / 1500: loss 777.277831
# iteration 100 / 1500: loss 2.335710
# iteration 200 / 1500: loss 2.085863
# iteration 300 / 1500: loss 2.106099
# iteration 400 / 1500: loss 2.069568
# iteration 500 / 1500: loss 2.013767
# iteration 600 / 1500: loss 2.099707
# iteration 700 / 1500: loss 2.088204
# iteration 800 / 1500: loss 2.062783
# iteration 900 / 1500: loss 2.101696
# iteration 1000 / 1500: loss 2.106352
# iteration 1100 / 1500: loss 2.099179
# iteration 1200 / 1500: loss 2.165895
# iteration 1300 / 1500: loss 2.094900
# iteration 1400 / 1500: loss 2.058273
# iteration 0 / 1500: loss 1552.989724
# iteration 100 / 1500: loss 2.176003
# iteration 200 / 1500: loss 2.140279
# iteration 300 / 1500: loss 2.194188
# iteration 400 / 1500: loss 2.162802
# iteration 500 / 1500: loss 2.100490
# iteration 600 / 1500: loss 2.148597
# iteration 700 / 1500: loss 2.204902
# iteration 800 / 1500: loss 2.188563
# iteration 900 / 1500: loss 2.127073
# iteration 1000 / 1500: loss 2.154516
# iteration 1100 / 1500: loss 2.181973
# iteration 1200 / 1500: loss 2.101018
# iteration 1300 / 1500: loss 2.183161
# iteration 1400 / 1500: loss 2.124711
# iteration 0 / 1500: loss 157.791953
# iteration 100 / 1500: loss 22.172479
# iteration 200 / 1500: loss 4.630685
# iteration 300 / 1500: loss 2.348393
# iteration 400 / 1500: loss 1.983721
# iteration 500 / 1500: loss 1.966898
# iteration 600 / 1500: loss 1.975371
# iteration 700 / 1500: loss 1.954378
# iteration 800 / 1500: loss 1.993064
# iteration 900 / 1500: loss 1.965824
# iteration 1000 / 1500: loss 1.886493
# iteration 1100 / 1500: loss 1.960566
# iteration 1200 / 1500: loss 1.962285
# iteration 1300 / 1500: loss 2.063595
# iteration 1400 / 1500: loss 1.912642
# iteration 0 / 1500: loss 312.732976
# iteration 100 / 1500: loss 7.297049
# iteration 200 / 1500: loss 2.097501
# iteration 300 / 1500: loss 2.082772
# iteration 400 / 1500: loss 2.056807
# iteration 500 / 1500: loss 2.116713
# iteration 600 / 1500: loss 1.958153
# iteration 700 / 1500: loss 2.021117
# iteration 800 / 1500: loss 2.012320
# iteration 900 / 1500: loss 2.006803
# iteration 1000 / 1500: loss 2.012061
# iteration 1100 / 1500: loss 2.015575
# iteration 1200 / 1500: loss 1.966778
# iteration 1300 / 1500: loss 2.040923
# iteration 1400 / 1500: loss 2.048246
# iteration 0 / 1500: loss 777.565911
# iteration 100 / 1500: loss 2.145451
# iteration 200 / 1500: loss 2.040953
# iteration 300 / 1500: loss 2.098475
# iteration 400 / 1500: loss 2.104042
# iteration 500 / 1500: loss 2.094981
# iteration 600 / 1500: loss 2.073169
# iteration 700 / 1500: loss 2.117703
# iteration 800 / 1500: loss 2.090147
# iteration 900 / 1500: loss 2.043534
# iteration 1000 / 1500: loss 2.073960
# iteration 1100 / 1500: loss 2.096815
# iteration 1200 / 1500: loss 2.030884
# iteration 1300 / 1500: loss 2.105568
# iteration 1400 / 1500: loss 2.152170
# iteration 0 / 1500: loss 1541.378822
# iteration 100 / 1500: loss 2.175240
# iteration 200 / 1500: loss 2.148676
# iteration 300 / 1500: loss 2.186608
# iteration 400 / 1500: loss 2.158052
# iteration 500 / 1500: loss 2.208686
# iteration 600 / 1500: loss 2.136654
# iteration 700 / 1500: loss 2.164330
# iteration 800 / 1500: loss 2.151511
# iteration 900 / 1500: loss 2.127254
# iteration 1000 / 1500: loss 2.147920
# iteration 1100 / 1500: loss 2.125454
# iteration 1200 / 1500: loss 2.163012
# iteration 1300 / 1500: loss 2.164077
# iteration 1400 / 1500: loss 2.163564
# lr 1.000000e-07 reg 5.000000e+03 train accuracy: 0.331714 val accuracy: 0.337000
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.357143 val accuracy: 0.367000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.327612 val accuracy: 0.341000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.301959 val accuracy: 0.321000
# lr 2.000000e-07 reg 5.000000e+03 train accuracy: 0.370653 val accuracy: 0.380000
# lr 2.000000e-07 reg 1.000000e+04 train accuracy: 0.356020 val accuracy: 0.368000
# lr 2.000000e-07 reg 2.500000e+04 train accuracy: 0.330816 val accuracy: 0.341000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.310551 val accuracy: 0.325000
# lr 5.000000e-07 reg 5.000000e+03 train accuracy: 0.367755 val accuracy: 0.393000
# lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.356959 val accuracy: 0.380000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.319245 val accuracy: 0.322000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.309837 val accuracy: 0.322000
# lr 8.000000e-07 reg 5.000000e+03 train accuracy: 0.377408 val accuracy: 0.378000
# lr 8.000000e-07 reg 1.000000e+04 train accuracy: 0.356673 val accuracy: 0.362000
# lr 8.000000e-07 reg 2.500000e+04 train accuracy: 0.326163 val accuracy: 0.350000
# lr 8.000000e-07 reg 5.000000e+04 train accuracy: 0.288510 val accuracy: 0.308000
# lr 1.000000e-06 reg 5.000000e+03 train accuracy: 0.365327 val accuracy: 0.371000
# lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.345265 val accuracy: 0.348000
# lr 1.000000e-06 reg 2.500000e+04 train accuracy: 0.325000 val accuracy: 0.320000
# lr 1.000000e-06 reg 5.000000e+04 train accuracy: 0.290816 val accuracy: 0.298000
# best validation accuracy achieved during cross-validation: 0.393000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.367000

# %% [markdown]
# **Inline Question** - *True or False*
#
# It's possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# *Your answer*: True
#
# *Your explanation*: SVM loss only cares about the fact that the difference between correst score and other scores is at least delta, but, Softmax doesn not have an optimum and tries to maximize the correct score as much as it can. Therefore, the loss value for the new data point may satisfy the SVM loss function but it does not happen for Softmax.

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
